# %% [markdown]
# # Measuring Blood sample on day 09-11-2023
#
# <img src="picture/20231109_booldOntThinSlide.jpg" alt="drawing" width="600"/>
#
# The blood is drawn an put on the thin slide.
#
# Laser power is set at 5.5 (0.39A, 30mW)
#
# The assessment duration is 120 seconds with no accumulation.
#
# Before the analyse, we performed
# `python3 _preprocess.py -d data/20231109-blood/ --upper_bound 1570 --lower_bound 0`
# to add meta data and limit the range of spectra

# %%
import spectrochempy as scp
from glob import glob
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.6.7<br/>© Copyright 2014-2023 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>

# %%
files = sorted(glob(pathname="data/20231109-blood/*"))
files
# Out:
# ['data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_29_32_01.txt',
#  'data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_32_25_01.txt',
#  'data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_34_53_01.txt',
#  'data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_37_02_01.txt',
#  'data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_39_17_01.txt',
#  'data/20231109-blood/blood_600_785 nm_120 s_1_2023_11_09_12_43_39_01.txt',
#  'data/20231109-blood/noise_600_785 nm_120 s_1_2023_11_09_11_20_16_01.txt',
#  'data/20231109-blood/nothing_600_785 nm_120 s_1_2023_11_09_12_10_47_01.txt',
#  'data/20231109-blood/slide_600_785 nm_120 s_1_2023_11_09_12_13_08_01.txt']

# %%
all = scp.read_labspec(files)
all
# Out:
# NDDataset: [float64] unitless (shape: (y:9, x:745))
# No such comm: 00b9d1c03df54621980bf49d25ad4377
# No such comm: 00b9d1c03df54621980bf49d25ad4377
# No such comm: 00b9d1c03df54621980bf49d25ad4377
# No such comm: 00b9d1c03df54621980bf49d25ad4377
# No such comm: 00b9d1c03df54621980bf49d25ad4377
# No such comm: a2671cb923f6497680c7445e413bd9cd
# No such comm: a2671cb923f6497680c7445e413bd9cd
# No such comm: a2671cb923f6497680c7445e413bd9cd
# No such comm: a2671cb923f6497680c7445e413bd9cd
# No such comm: a2671cb923f6497680c7445e413bd9cd
# No such comm: c7655d7a34b9431b81fb42a90e521d36
# No such comm: c7655d7a34b9431b81fb42a90e521d36
# No such comm: c7655d7a34b9431b81fb42a90e521d36
# No such comm: c7655d7a34b9431b81fb42a90e521d36
# No such comm: c7655d7a34b9431b81fb42a90e521d36
# No such comm: d94104c0cc6349dc844db7da97c006ee
# No such comm: d94104c0cc6349dc844db7da97c006ee
# No such comm: d94104c0cc6349dc844db7da97c006ee
# No such comm: d94104c0cc6349dc844db7da97c006ee
# No such comm: d94104c0cc6349dc844db7da97c006ee
# No such comm: ae040b9da6644a16bf6e4967aba73d55
# No such comm: ae040b9da6644a16bf6e4967aba73d55
# No such comm: ae040b9da6644a16bf6e4967aba73d55
# No such comm: ae040b9da6644a16bf6e4967aba73d55
# No such comm: ae040b9da6644a16bf6e4967aba73d55
# No such comm: 365971053fd840a5826dea57e72fb9ed
# No such comm: 365971053fd840a5826dea57e72fb9ed
# No such comm: 365971053fd840a5826dea57e72fb9ed
# No such comm: 365971053fd840a5826dea57e72fb9ed
# No such comm: 365971053fd840a5826dea57e72fb9ed
# No such comm: e0f7eabeb8ba477e9f829599144c66d9
# No such comm: e0f7eabeb8ba477e9f829599144c66d9
# No such comm: e0f7eabeb8ba477e9f829599144c66d9
# No such comm: e0f7eabeb8ba477e9f829599144c66d9
# No such comm: e0f7eabeb8ba477e9f829599144c66d9
# No such comm: a83c76eab9914c0a853b01e940677d0d
# No such comm: a83c76eab9914c0a853b01e940677d0d
# No such comm: a83c76eab9914c0a853b01e940677d0d
# No such comm: a83c76eab9914c0a853b01e940677d0d
# No such comm: a83c76eab9914c0a853b01e940677d0d
# No such comm: 1a744cb16e014c3ba68a242e3f36db81
# No such comm: 1a744cb16e014c3ba68a242e3f36db81
# No such comm: 1a744cb16e014c3ba68a242e3f36db81
# No such comm: 1a744cb16e014c3ba68a242e3f36db81
# No such comm: 1a744cb16e014c3ba68a242e3f36db81
# No such comm: 84458b40aa144962b628ecf97fe91d7f
# No such comm: 84458b40aa144962b628ecf97fe91d7f
# No such comm: 84458b40aa144962b628ecf97fe91d7f
# No such comm: 84458b40aa144962b628ecf97fe91d7f
# No such comm: 84458b40aa144962b628ecf97fe91d7f
# No such comm: d3a9182680ac415a89630427ef78242e
# No such comm: d3a9182680ac415a89630427ef78242e
# No such comm: d3a9182680ac415a89630427ef78242e
# No such comm: d3a9182680ac415a89630427ef78242e
# No such comm: d3a9182680ac415a89630427ef78242e
# No such comm: 838fa7305caf4d129405dee892b93a80
# No such comm: 838fa7305caf4d129405dee892b93a80
# No such comm: 838fa7305caf4d129405dee892b93a80
# No such comm: 838fa7305caf4d129405dee892b93a80
# No such comm: 838fa7305caf4d129405dee892b93a80
# No such comm: eaa6c20c00e04f5087cd5d249c581573
# No such comm: eaa6c20c00e04f5087cd5d249c581573
# No such comm: eaa6c20c00e04f5087cd5d249c581573
# No such comm: eaa6c20c00e04f5087cd5d249c581573
# No such comm: eaa6c20c00e04f5087cd5d249c581573
# No such comm: 35b4031d78cf4009a37037bbbff8d781
# No such comm: 35b4031d78cf4009a37037bbbff8d781
# No such comm: 35b4031d78cf4009a37037bbbff8d781
# No such comm: 35b4031d78cf4009a37037bbbff8d781
# No such comm: 35b4031d78cf4009a37037bbbff8d781
# No such comm: 472fb95b3f2c47d69fd94bcb5e2f7b76
# No such comm: 472fb95b3f2c47d69fd94bcb5e2f7b76
# No such comm: 472fb95b3f2c47d69fd94bcb5e2f7b76
# No such comm: 472fb95b3f2c47d69fd94bcb5e2f7b76
# No such comm: 472fb95b3f2c47d69fd94bcb5e2f7b76
# No such comm: 1f5c049f31f84a618248c541c01cc682
# No such comm: 1f5c049f31f84a618248c541c01cc682
# No such comm: 1f5c049f31f84a618248c541c01cc682
# No such comm: 1f5c049f31f84a618248c541c01cc682
# No such comm: 1f5c049f31f84a618248c541c01cc682
# No such comm: 523d9f4f45d34a6f98cd7250bce00899
# No such comm: 523d9f4f45d34a6f98cd7250bce00899
# No such comm: 523d9f4f45d34a6f98cd7250bce00899
# No such comm: 523d9f4f45d34a6f98cd7250bce00899
# No such comm: 523d9f4f45d34a6f98cd7250bce00899
# No such comm: 073071cdaccd49e8a8b6af77ca9407ce
# No such comm: 073071cdaccd49e8a8b6af77ca9407ce
# No such comm: 073071cdaccd49e8a8b6af77ca9407ce
# No such comm: 073071cdaccd49e8a8b6af77ca9407ce
# No such comm: 073071cdaccd49e8a8b6af77ca9407ce

# %%
blood = all[0:6, 0:500]
noise = all[6, 0:500]
nothing = all[7, 0:500]
slide = all[8, 0:500]

# %%
ax = blood.plot()
ax.set_title(f"Plot raw result of 6 Raman Spectra measure from the same blood sample.")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ax = scp.plot_multiple(method="pen", datasets=[noise, nothing, slide], labels=['noise', 'nothing', 'slide'], legend='best')
ax.set_title("Raman Spectra of noises.")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Baseline Removal

# %%
# Baseline at 1450
blc = scp.Baseline(ranges=(1430,1470))
blc.fit(blood)
ax = blc.transform().plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f'Baseline Correction using spectra at 1450 cm^-1')
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Baseline at 1550
blc = scp.Baseline(ranges=(1530,1570))
blc.fit(blood)
ax = blc.transform().plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f'Baseline Correction using spectra at 1550 cm^-1')
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Remove Noise then Baseline Correction

# %%
blc = scp.Baseline(ranges=(1425,1475))
blc.fit(blood - nothing)
ax = blc.transform().smooth(15).plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f"6 Raman Spectra of the same blood sample after remove Noise and Beasline Correction at 1450 cm^-1")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blc = scp.Baseline(ranges=(1525,1575))
blc.fit(blood - nothing)
ax = blc.transform().smooth(15).plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f"6 Raman Spectra of the same blood sample after remove Noise and Beasline Correction at 1550 cm^-1")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Study the measurement at finger
#
# We keep setting the same

# %%
# scp.read_labspec()
files = sorted(glob(pathname="data/20231109-finger/*"))
files
# Out:
# ['data/20231109-finger/2index_600_785 nm_120 s_1_2023_11_09_17_55_31_01.txt',
#  'data/20231109-finger/2index_600_785 nm_120 s_1_2023_11_09_17_57_49_01.txt',
#  'data/20231109-finger/2middle_600_785 nm_120 s_1_2023_11_09_18_00_35_01.txt',
#  'data/20231109-finger/2middle_600_785 nm_120 s_1_2023_11_09_18_03_00_01.txt',
#  'data/20231109-finger/2nailfold_600_785 nm_120 s_1_2023_11_09_18_05_50_01.txt',
#  'data/20231109-finger/2nailfold_600_785 nm_120 s_1_2023_11_09_18_08_11_01.txt',
#  'data/20231109-finger/2noise_600_785 nm_120 s_1_2023_11_09_17_50_28_01.txt',
#  'data/20231109-finger/2noise_600_785 nm_120 s_1_2023_11_09_18_12_57_01.txt',
#  'data/20231109-finger/2nothing_600_785 nm_120 s_1_2023_11_09_17_52_45_01.txt',
#  'data/20231109-finger/2nothing_600_785 nm_120 s_1_2023_11_09_18_10_33_01.txt']

# %%
all = scp.read_labspec(files)
all
# Out:
# NDDataset: [float64] unitless (shape: (y:10, x:745))
# No such comm: fc3b1f32928849ae983aebd9ff9bad0e
# No such comm: fc3b1f32928849ae983aebd9ff9bad0e
# No such comm: fc3b1f32928849ae983aebd9ff9bad0e
# No such comm: fc3b1f32928849ae983aebd9ff9bad0e
# No such comm: fc3b1f32928849ae983aebd9ff9bad0e
# No such comm: a501a274c1d244e4912fcde88fbce0ec
# No such comm: a501a274c1d244e4912fcde88fbce0ec
# No such comm: a501a274c1d244e4912fcde88fbce0ec
# No such comm: a501a274c1d244e4912fcde88fbce0ec
# No such comm: a501a274c1d244e4912fcde88fbce0ec
# No such comm: a236a814b64f4e8d9f87cf3f3529c4be
# No such comm: a236a814b64f4e8d9f87cf3f3529c4be
# No such comm: a236a814b64f4e8d9f87cf3f3529c4be
# No such comm: a236a814b64f4e8d9f87cf3f3529c4be
# No such comm: a236a814b64f4e8d9f87cf3f3529c4be
# No such comm: 3d6c313c5d81445ba717cc8722655db5
# No such comm: 3d6c313c5d81445ba717cc8722655db5
# No such comm: 3d6c313c5d81445ba717cc8722655db5
# No such comm: 3d6c313c5d81445ba717cc8722655db5
# No such comm: 3d6c313c5d81445ba717cc8722655db5
# No such comm: 0d9fbb32d690441185991c5cd6cb1b05
# No such comm: 0d9fbb32d690441185991c5cd6cb1b05
# No such comm: 0d9fbb32d690441185991c5cd6cb1b05
# No such comm: 0d9fbb32d690441185991c5cd6cb1b05
# No such comm: 0d9fbb32d690441185991c5cd6cb1b05
# No such comm: b30a43e4b56040449314e9525f126b0c
# No such comm: b30a43e4b56040449314e9525f126b0c
# No such comm: b30a43e4b56040449314e9525f126b0c
# No such comm: b30a43e4b56040449314e9525f126b0c
# No such comm: b30a43e4b56040449314e9525f126b0c
# No such comm: cd3cfba22cb6427e94e8f4550c9817d7
# No such comm: cd3cfba22cb6427e94e8f4550c9817d7
# No such comm: cd3cfba22cb6427e94e8f4550c9817d7
# No such comm: cd3cfba22cb6427e94e8f4550c9817d7
# No such comm: cd3cfba22cb6427e94e8f4550c9817d7
# No such comm: 6e0be8c71d9549278a57a1ad26ef2876
# No such comm: 6e0be8c71d9549278a57a1ad26ef2876
# No such comm: 6e0be8c71d9549278a57a1ad26ef2876
# No such comm: 6e0be8c71d9549278a57a1ad26ef2876
# No such comm: 6e0be8c71d9549278a57a1ad26ef2876
# No such comm: 58d8082d72ad46ef8bbbf2a724fb0c2d
# No such comm: 58d8082d72ad46ef8bbbf2a724fb0c2d
# No such comm: 58d8082d72ad46ef8bbbf2a724fb0c2d
# No such comm: 58d8082d72ad46ef8bbbf2a724fb0c2d
# No such comm: 58d8082d72ad46ef8bbbf2a724fb0c2d
# No such comm: f3b0fb50dbba4e69982ca14f9a3c1991
# No such comm: f3b0fb50dbba4e69982ca14f9a3c1991
# No such comm: f3b0fb50dbba4e69982ca14f9a3c1991
# No such comm: f3b0fb50dbba4e69982ca14f9a3c1991
# No such comm: f3b0fb50dbba4e69982ca14f9a3c1991
# No such comm: ccddf491cd0f42dc83b001035b3eca1e
# No such comm: ccddf491cd0f42dc83b001035b3eca1e
# No such comm: ccddf491cd0f42dc83b001035b3eca1e
# No such comm: ccddf491cd0f42dc83b001035b3eca1e
# No such comm: ccddf491cd0f42dc83b001035b3eca1e
# No such comm: 06bbd55838d34cd289a23b36355a380f
# No such comm: 06bbd55838d34cd289a23b36355a380f
# No such comm: 06bbd55838d34cd289a23b36355a380f
# No such comm: 06bbd55838d34cd289a23b36355a380f
# No such comm: 06bbd55838d34cd289a23b36355a380f
# No such comm: 61bfd1601d424d9b88f1e5627bc3f3f7
# No such comm: 61bfd1601d424d9b88f1e5627bc3f3f7
# No such comm: 61bfd1601d424d9b88f1e5627bc3f3f7
# No such comm: 61bfd1601d424d9b88f1e5627bc3f3f7
# No such comm: 61bfd1601d424d9b88f1e5627bc3f3f7
# No such comm: ed5999b24adb4290bb784b81e4f45fc1
# No such comm: ed5999b24adb4290bb784b81e4f45fc1
# No such comm: ed5999b24adb4290bb784b81e4f45fc1
# No such comm: ed5999b24adb4290bb784b81e4f45fc1
# No such comm: ed5999b24adb4290bb784b81e4f45fc1

# %%
index = all[0:2, 0:500]
middle = all[2:4, 0:500]
nailfold = all[4:6, 0:500]
noise = all[6, 0:500]
nothing = all[8, 0:500]

# %%
ax = scp.plot_multiple(method="pen", datasets=[noise, nothing], labels=['noise', 'nothing'], legend='best')
ax.set_title("Raman Spectra of noises.")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blc = scp.Baseline(ranges=(1425,1475))
blc.fit(index - nothing)
ax = blc.transform().smooth(15).plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f"2 samples at index after remove Noise and Beasline Correction at 1450 cm^-1")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blc = scp.Baseline(ranges=(1425,1475))
blc.fit(middle - nothing)
ax = blc.transform().smooth(15).plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f"2 samples at middle after remove Noise and Beasline Correction at 1450 cm^-1")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blc = scp.Baseline(ranges=(1425,1475))
blc.fit(nailfold - nothing)
ax = blc.transform().smooth(15).plot()
ax.vlines(x=1125, ymin=-500, ymax=10000)
ax.vlines(x=759, ymin=-500, ymax=10000)
ax.vlines(x=1450, ymin=-500, ymax=10000)
ax.vlines(x=1550, ymin=-500, ymax=10000)
ax.set_title(f"2 samples at Nailfold after remove Noise and Beasline Correction at 1450 cm^-1")
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
