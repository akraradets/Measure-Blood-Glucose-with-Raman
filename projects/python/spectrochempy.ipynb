# %%
import spectrochempy as scp
from spectrochempy.core.readers import read_labspec
from glob import glob
print(glob(pathname="data/20231030/*"))
A = scp.read_labspec('data/20231030', merge=True)
A
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.6.7<br/>© Copyright 2014-2023 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>
# ['data/20231030/wrist_600_785 nm_10 s_1_2023_10_30_15_18_04_01.txt', 'data/20231030/wristback_600_785 nm_10 s_1_2023_10_30_15_22_22_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_53_50_01.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_34_38_01.txt', 'data/20231030/noise_600_785 nm_10 s_1_2023_10_30_16_29_00_01.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_38_25_01.txt', 'data/20231030/tip_600_785 nm_10 s_1_2023_10_30_14_54_38_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_52_23_01.txt', 'data/20231030/tip_600_785 nm_10 s_1_2023_10_30_14_55_12_01.txt', 'data/20231030/wristback_600_785 nm_10 s_1_2023_10_30_15_20_07_01.txt', 'data/20231030/noise_600_785 nm_10 s_1_2023_10_30_14_57_37_01.txt', 'data/20231030/noise_600_785 nm_14_51_46_01.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_33_44_01.txt', 'data/20231030/nailfold_600_785 nm_10 s_1_2023_10_30_14_59_47_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_53_15_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_51_43_01.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_37_45_01.txt', 'data/20231030/noise_600_785 nm_10 s_1_2023_10_30_15_43_42_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_50_18_01.txt', 'data/20231030/wristback_600_785 nm_10 s_1_2023_10_30_15_21_49_01.txt', 'data/20231030/noise_600_785 nm_10 s_1_2023_10_30_15_03_32_01.txt', 'data/20231030/bloodtip_600_785 nm_10 s_1_2023_10_30_15_54_39_01.txt', 'data/20231030/blood_600_785 nm_10 s_3_2023_10_30_15_32_31.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_32_13_01.txt', 'data/20231030/tip_600_785 nm_10 s_1_2023_10_30_14_55_47_01.txt', 'data/20231030/nailfold_600_785 nm_10 s_1_2023_10_30_15_00_33_01.txt', 'data/20231030/tip_600_785 nm_10 s_1_2023_10_30_14_56_57_01.txt', 'data/20231030/wrist_600_785 nm_10 s_1_2023_10_30_15_16_43_01.txt', 'data/20231030/wristback_600_785 nm_10 s_1_2023_10_30_15_20_59_01.txt', 'data/20231030/thenar_600_785 nm_10 s_1_2023_10_30_15_18_57_01.txt', 'data/20231030/blood_600_785 nm_10 s_1_2023_10_30_15_36_57_01.txt', 'data/20231030/thenar_600_785 nm_10 s_1_2023_10_30_15_15_07_01.txt', 'data/20231030/blood_600_785 nm_2 s_1_2023_10_30_15_34_55.txt', 'data/20231030/tip_600_785 nm_10 s_1_2023_10_30_14_56_22_01.txt', 'data/20231030/nailfold_600_785 nm_10 s_1_2023_10_30_15_02_00_01.txt']
# NDDataset: [float64] unitless (shape: (y:34, x:762))

# %%
A.plot()
# Out:
# <_Axes: xlabel='Raman shift $\\mathrm{/\\ \\mathrm{cm}^{-1}}$', ylabel='Counts $\\mathrm{}$'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
B = A[:, 0:600]
B.plot()
# Out:
# No such comm: 23687820b3b14fecb3814c78a14ddd4c
# No such comm: 42165d6074d940fb804b504315f2a9f6
# No such comm: 42165d6074d940fb804b504315f2a9f6
# No such comm: 42165d6074d940fb804b504315f2a9f6
# No such comm: 3f56bde6aa8d4502af364472c3937620
# No such comm: 3f56bde6aa8d4502af364472c3937620
# No such comm: 3f56bde6aa8d4502af364472c3937620
# No such comm: d76ea52be3c8499facdc4d977218f2e6
# No such comm: d76ea52be3c8499facdc4d977218f2e6
# No such comm: d76ea52be3c8499facdc4d977218f2e6
# No such comm: 4b16c0f4495d43a99a383addc7ff2590
# No such comm: 4b16c0f4495d43a99a383addc7ff2590
# No such comm: 4b16c0f4495d43a99a383addc7ff2590
# No such comm: a6237508727c4f5ab5cf958b7685c58c
# No such comm: a6237508727c4f5ab5cf958b7685c58c
# No such comm: a6237508727c4f5ab5cf958b7685c58c
# No such comm: b04e09244888499c869b80704c3ca4da
# No such comm: b04e09244888499c869b80704c3ca4da
# No such comm: b04e09244888499c869b80704c3ca4da
# No such comm: 3f580794840140dbb031657788907ea8
# No such comm: 3f580794840140dbb031657788907ea8
# No such comm: 3f580794840140dbb031657788907ea8
# No such comm: 2616a5a2f124473993b2299c7f97bc67
# No such comm: 2616a5a2f124473993b2299c7f97bc67
# No such comm: 2616a5a2f124473993b2299c7f97bc67
# No such comm: b7bea528cb264452a5214d75b19cd855
# No such comm: b7bea528cb264452a5214d75b19cd855
# No such comm: b7bea528cb264452a5214d75b19cd855
# No such comm: 8bc8ee5dc5c744a08acfea2ee240cae8
# No such comm: 8bc8ee5dc5c744a08acfea2ee240cae8
# No such comm: 8bc8ee5dc5c744a08acfea2ee240cae8
# No such comm: 3dc1d6409fd24e839ddf5f55ad6c38ba
# No such comm: 3dc1d6409fd24e839ddf5f55ad6c38ba
# No such comm: 3dc1d6409fd24e839ddf5f55ad6c38ba
# No such comm: a5befb79c4e14a7b879d214f630dad89
# No such comm: a5befb79c4e14a7b879d214f630dad89
# No such comm: a5befb79c4e14a7b879d214f630dad89
# No such comm: 4d273d688edc425f962088d2fe2ea73e
# No such comm: 4d273d688edc425f962088d2fe2ea73e
# No such comm: 4d273d688edc425f962088d2fe2ea73e
# No such comm: 1e165f2e9c0a44048f846d74c0903ca0
# No such comm: 1e165f2e9c0a44048f846d74c0903ca0
# No such comm: 1e165f2e9c0a44048f846d74c0903ca0
# No such comm: 97f500075ad748169de50725a2697c3e
# No such comm: 97f500075ad748169de50725a2697c3e
# No such comm: 97f500075ad748169de50725a2697c3e
# No such comm: d674901085b74bb9b1720e798e763a4d
# No such comm: d674901085b74bb9b1720e798e763a4d
# No such comm: d674901085b74bb9b1720e798e763a4d
# <_Axes: xlabel='Raman shift $\\mathrm{/\\ \\mathrm{cm}^{-1}}$', ylabel='Counts $\\mathrm{}$'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
blc = scp.Baseline(log_level="INFO")
blc.model = "detrend"
blc.fit(B)
corr = blc.transform()
baseline = blc.baseline
_ = corr.plot()

# %%
B_asls = scp.asls(B)
B_asls.plot()
# Out:
# <_Axes: xlabel='Raman shift $\\mathrm{/\\ \\mathrm{cm}^{-1}}$', ylabel='Counts $\\mathrm{}$'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
out = scp.BaselineCorrector(B)
# Out:
# HBox(children=(VBox(), VBox()))
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#  ERROR | IndexError: Empty array of shape (34, 0) resulted from slicing.
# Check the indexes and make sure to use floats for location slicing
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Baseline correct for each sample

# %%
import spectrochempy as scp
from glob import glob

# %%
sample_names = ['blood', 'bloodtip', 'nailfold', 'noise', 'thenar', 'tip', 'wrist', 'wristback']

for sample_name in sample_names:
    try:
        globals()[sample_name] = scp.read_labspec(glob(pathname=f"data/20231030/{sample_name}*"))
    except Exception as e:
        print(sample_name)
# Out:
# No such comm: f12bc2ce7b504292a38a2af2505fc125
# No such comm: f12bc2ce7b504292a38a2af2505fc125
# No such comm: f12bc2ce7b504292a38a2af2505fc125
# No such comm: 276d3e85eef14a7eb097c53f6b21e7a1
# No such comm: 276d3e85eef14a7eb097c53f6b21e7a1
# No such comm: 276d3e85eef14a7eb097c53f6b21e7a1
# No such comm: 87d117f4f2d04c939aa9e679449a790b
# No such comm: 87d117f4f2d04c939aa9e679449a790b
# No such comm: 87d117f4f2d04c939aa9e679449a790b
# No such comm: 5fca9ba209db48f8a89cbd4b88c27e34
# No such comm: 5fca9ba209db48f8a89cbd4b88c27e34
# No such comm: 5fca9ba209db48f8a89cbd4b88c27e34
# No such comm: 4baf84ea34ee4f9baec617b44cded5fc
# No such comm: 4baf84ea34ee4f9baec617b44cded5fc
# No such comm: 4baf84ea34ee4f9baec617b44cded5fc
# No such comm: 1f18c8111ff74a4d90ae567dd1f2f6af
# No such comm: 1f18c8111ff74a4d90ae567dd1f2f6af
# No such comm: 1f18c8111ff74a4d90ae567dd1f2f6af
# No such comm: 3f1232f65f944a67948f7cfbf42823b7
# No such comm: 3f1232f65f944a67948f7cfbf42823b7
# No such comm: 3f1232f65f944a67948f7cfbf42823b7
# No such comm: 8c33dd3c8a1d4a0a89e00afeccb317b9
# No such comm: 8c33dd3c8a1d4a0a89e00afeccb317b9
# No such comm: 8c33dd3c8a1d4a0a89e00afeccb317b9
# No such comm: 98ccf30ac6e94531a4b7c2f95db1a3bd
# No such comm: 98ccf30ac6e94531a4b7c2f95db1a3bd
# No such comm: 98ccf30ac6e94531a4b7c2f95db1a3bd
# No such comm: 398afef170104393b6f54e351d263ad0
# No such comm: 398afef170104393b6f54e351d263ad0
# No such comm: 398afef170104393b6f54e351d263ad0
# No such comm: 355e1ca43a874f6c9116201fd543fff3
# No such comm: 355e1ca43a874f6c9116201fd543fff3
# No such comm: 355e1ca43a874f6c9116201fd543fff3
# No such comm: b9fc4d1b809b450096a77bb91ab6ebec
# No such comm: b9fc4d1b809b450096a77bb91ab6ebec
# No such comm: b9fc4d1b809b450096a77bb91ab6ebec
# No such comm: 41dc601a0da848b48581e833d7cc053d
# No such comm: 41dc601a0da848b48581e833d7cc053d
# No such comm: 41dc601a0da848b48581e833d7cc053d
# No such comm: 9671b9def9884c1eb9c3be263c2bc3e7
# No such comm: 9671b9def9884c1eb9c3be263c2bc3e7
# No such comm: 9671b9def9884c1eb9c3be263c2bc3e7
# No such comm: e7cbabe1db11484db217e871405020d0
# No such comm: e7cbabe1db11484db217e871405020d0
# No such comm: e7cbabe1db11484db217e871405020d0
# No such comm: 7450736ded074df69bec371db287060e
# No such comm: 7450736ded074df69bec371db287060e
# No such comm: 7450736ded074df69bec371db287060e
# No such comm: 1f620de55bee467c91cab61064471d58
# No such comm: 1f620de55bee467c91cab61064471d58
# No such comm: 1f620de55bee467c91cab61064471d58
# No such comm: 68aba623e4bc404d817048e8839b5290
# No such comm: 68aba623e4bc404d817048e8839b5290
# No such comm: 68aba623e4bc404d817048e8839b5290
# No such comm: 395f98ceb9df4f039ba4b09640e853f8
# No such comm: 395f98ceb9df4f039ba4b09640e853f8
# No such comm: 395f98ceb9df4f039ba4b09640e853f8
# No such comm: 5d256a2d0d2f4f4097f07ec299731711
# No such comm: 5d256a2d0d2f4f4097f07ec299731711
# No such comm: 5d256a2d0d2f4f4097f07ec299731711
# No such comm: 9ffdf0f57b784828818523e8f0ab61ff
# No such comm: 9ffdf0f57b784828818523e8f0ab61ff
# No such comm: 9ffdf0f57b784828818523e8f0ab61ff
# No such comm: 4fad46dd5f4f46b6aa5a3f9502dc0517
# No such comm: 4fad46dd5f4f46b6aa5a3f9502dc0517
# No such comm: 4fad46dd5f4f46b6aa5a3f9502dc0517
# No such comm: 38370b130feb45409cb6e8376e50edf2
# No such comm: 38370b130feb45409cb6e8376e50edf2
# No such comm: 38370b130feb45409cb6e8376e50edf2
# No such comm: 71edcddd89cf44479a124236f0af6aef
# No such comm: 71edcddd89cf44479a124236f0af6aef
# No such comm: 71edcddd89cf44479a124236f0af6aef
# No such comm: 93068aa5168d48d2b23b34a0ce3c90ae
# No such comm: 93068aa5168d48d2b23b34a0ce3c90ae
# No such comm: 93068aa5168d48d2b23b34a0ce3c90ae
# No such comm: c69e97a21d9f47c083214dd31e0cd0ad
# No such comm: c69e97a21d9f47c083214dd31e0cd0ad
# No such comm: c69e97a21d9f47c083214dd31e0cd0ad
# No such comm: ba6c93e4dae84262a96b1c5aecdf22f8
# No such comm: ba6c93e4dae84262a96b1c5aecdf22f8
# No such comm: ba6c93e4dae84262a96b1c5aecdf22f8
# No such comm: ef1d0df016b243368def1834daba9843
# No such comm: ef1d0df016b243368def1834daba9843
# No such comm: ef1d0df016b243368def1834daba9843
# No such comm: 7d184a1eeda044a2822580f5689e48df
# No such comm: 7d184a1eeda044a2822580f5689e48df
# No such comm: 7d184a1eeda044a2822580f5689e48df
# No such comm: 0a9eaa0aef784be2be156913e80f6435
# No such comm: 0a9eaa0aef784be2be156913e80f6435
# No such comm: 0a9eaa0aef784be2be156913e80f6435
# No such comm: 046932a5b6d6494c8643e36dc73b2b4c
# No such comm: 046932a5b6d6494c8643e36dc73b2b4c
# No such comm: 046932a5b6d6494c8643e36dc73b2b4c
# No such comm: ad7ec1013b3a4e3ca2aedc38637e0785
# No such comm: ad7ec1013b3a4e3ca2aedc38637e0785
# No such comm: ad7ec1013b3a4e3ca2aedc38637e0785
# No such comm: a5741bc6a5414820a4b40808701bc519
# No such comm: a5741bc6a5414820a4b40808701bc519
# No such comm: a5741bc6a5414820a4b40808701bc519
# No such comm: e57f57a9b87a4a30888f3ae3e478037f
# No such comm: e57f57a9b87a4a30888f3ae3e478037f
# No such comm: e57f57a9b87a4a30888f3ae3e478037f
# No such comm: 044ef26a552442f389cb0580878bab33
# No such comm: 044ef26a552442f389cb0580878bab33
# No such comm: 044ef26a552442f389cb0580878bab33
# No such comm: b0becd3e3c5e4c14a9af201f88b739aa
# No such comm: b0becd3e3c5e4c14a9af201f88b739aa
# No such comm: b0becd3e3c5e4c14a9af201f88b739aa
# No such comm: a7516c601b7e4c1fb66a40651bfa3525
# No such comm: a7516c601b7e4c1fb66a40651bfa3525
# No such comm: a7516c601b7e4c1fb66a40651bfa3525
# No such comm: 154b0d0aaade4b3cb30d4993445ad8aa
# No such comm: 154b0d0aaade4b3cb30d4993445ad8aa
# No such comm: 154b0d0aaade4b3cb30d4993445ad8aa
# No such comm: 8d0bdae4b7ba4f3b8cbb1013c1c0cb2c
# No such comm: 8d0bdae4b7ba4f3b8cbb1013c1c0cb2c
# No such comm: 8d0bdae4b7ba4f3b8cbb1013c1c0cb2c
# No such comm: b760944478b8406ba960af89dfaaf98f
# No such comm: b760944478b8406ba960af89dfaaf98f
# No such comm: b760944478b8406ba960af89dfaaf98f
# No such comm: 41b48181259246df8ea814a58ca64cf7
# No such comm: 41b48181259246df8ea814a58ca64cf7
# No such comm: 41b48181259246df8ea814a58ca64cf7
# No such comm: 84a2c3f853384a5091977db7ac2da749
# No such comm: 84a2c3f853384a5091977db7ac2da749
# No such comm: 84a2c3f853384a5091977db7ac2da749
# No such comm: 3db163d38a384a46b135858bd3760761
# No such comm: 3db163d38a384a46b135858bd3760761
# No such comm: 3db163d38a384a46b135858bd3760761
# No such comm: 677ea94f8dcc41869c8c2e7bb0c61bbc
# No such comm: 677ea94f8dcc41869c8c2e7bb0c61bbc
# No such comm: 677ea94f8dcc41869c8c2e7bb0c61bbc

# %%
for sample_name in sample_names:
    scp.asls(globals()[sample_name][:, 0:600]).plot(title=sample_name)
# Out:
#  WARNING | (RuntimeWarning) More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
